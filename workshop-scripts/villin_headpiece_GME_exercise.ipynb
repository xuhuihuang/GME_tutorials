# %%
# !wget https://github.com/xuhuihuang/GME_tutorials/raw/main/tutorials/villin_headpiece/MacroGME/tica/TPM.npy
# !wget https://github.com/xuhuihuang/GME_tutorials/raw/main/tutorials/villin_headpiece/MacroGME/tica/bootstrap_TPM.npy
# !wget https://github.com/xuhuihuang/GME_tutorials/raw/main/quasi-MSM/qmsm.py
# !wget https://github.com/xuhuihuang/GME_tutorials/raw/main/IGME/igme.py
# Out:
# --2024-08-12 02:10:31--  https://github.com/xuhuihuang/GME_tutorials/raw/main/tutorials/villin_headpiece/MacroGME/tica/TPM.npy
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/xuhuihuang/GME_tutorials/main/tutorials/villin_headpiece/MacroGME/tica/TPM.npy [following]
# --2024-08-12 02:10:31--  https://raw.githubusercontent.com/xuhuihuang/GME_tutorials/main/tutorials/villin_headpiece/MacroGME/tica/TPM.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38528 (38K) [application/octet-stream]
# Saving to: ‘TPM.npy’
#
# TPM.npy             100%[===================>]  37.62K  --.-KB/s    in 0.007s
#
# 2024-08-12 02:10:31 (5.49 MB/s) - ‘TPM.npy’ saved [38528/38528]
#
# --2024-08-12 02:10:31--  https://github.com/xuhuihuang/GME_tutorials/raw/main/tutorials/villin_headpiece/MacroGME/tica/bootstrap_TPM.npy
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/xuhuihuang/GME_tutorials/main/tutorials/villin_headpiece/MacroGME/tica/bootstrap_TPM.npy [following]
# --2024-08-12 02:10:32--  https://raw.githubusercontent.com/xuhuihuang/GME_tutorials/main/tutorials/villin_headpiece/MacroGME/tica/bootstrap_TPM.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1920128 (1.8M) [application/octet-stream]
# Saving to: ‘bootstrap_TPM.npy’
#
# bootstrap_TPM.npy   100%[===================>]   1.83M  --.-KB/s    in 0.05s
#
# 2024-08-12 02:10:32 (39.6 MB/s) - ‘bootstrap_TPM.npy’ saved [1920128/1920128]
#
# --2024-08-12 02:10:32--  https://github.com/xuhuihuang/GME_tutorials/raw/main/quasi-MSM/qmsm.py
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/xuhuihuang/GME_tutorials/main/quasi-MSM/qmsm.py [following]
# --2024-08-12 02:10:32--  https://raw.githubusercontent.com/xuhuihuang/GME_tutorials/main/quasi-MSM/qmsm.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12116 (12K) [text/plain]
# Saving to: ‘qmsm.py’
#
# qmsm.py             100%[===================>]  11.83K  --.-KB/s    in 0s
#
# 2024-08-12 02:10:32 (33.3 MB/s) - ‘qmsm.py’ saved [12116/12116]
#
# --2024-08-12 02:10:32--  https://github.com/xuhuihuang/GME_tutorials/raw/main/IGME/igme.py
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/xuhuihuang/GME_tutorials/main/IGME/igme.py [following]
# --2024-08-12 02:10:32--  https://raw.githubusercontent.com/xuhuihuang/GME_tutorials/main/IGME/igme.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21021 (21K) [text/plain]
# Saving to: ‘igme.py’
#
# igme.py             100%[===================>]  20.53K  --.-KB/s    in 0.001s
#
# 2024-08-12 02:10:33 (17.1 MB/s) - ‘igme.py’ saved [21021/21021]

# %%
# @title Import necessary packages
from igme import IGME
from qmsm import QuasiMSM, MSM
import numpy as np
from matplotlib import pyplot as plt

TPM = np.load("TPM.npy")
bootstrap_TPM = np.load("bootstrap_TPM.npy")
